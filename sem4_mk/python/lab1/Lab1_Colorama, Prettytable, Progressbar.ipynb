# %% [markdown]
# # Лабораторная работа 1

# %% [markdown]
# ## Библиотеки Colorama, Prettytable, Progressbar

# %% [markdown]
# **1.** Пользователь вводит строку - предложение на русском языке. Программа выводит это предложение, при этом гласные буквы выводятся шрифтом красного цвета, согласные - синего, все остальные символы - черным.

# %%
# Ваш код здесь

# %% [markdown]
# **2.** Напишите программу, которая выполняет копирование каталога с большим количеством файлов большого объема (путь к каталогу задайте константой), отображая процесс в виде progressbar-а (пропорционально доле обработанных файлов). Если это выполняется слишком быстро, то добавьте замедление с помощью time.sleep. После завершения копирования выведите сообщение зелеными буквами, что копирование завершено. При возникновении ошибки - выведите сообщение красными буквами.

# %%
# Ваш код здесь

# %% [markdown]
# **3.** Из файла считываются данные про друзей и их дни рождения. Этими данными заполняется таблица с 4 столбцами - имя друга, день рождения, месяц рождения, год рождения. Данные выводятся в опредененном вами формате в виде таблицы с помощью модуля prettytable (используйте разные выравнивания для разных столбцов).
#
# Программа определяет друга, у которого будет ближайший день рождения (сегодняшняя дата определяется автоматически) и выводит имя этого друга и сколько дней осталось до праздника. При этом, если день рождени зимой - то имя друга выводится белыми буквами на синем фоне, весной - желтыми буквами на зеленом фоне, летом - красными буквами на желтом фоне, оченью - цвета на ваш выбор.

# %%
# Ваш код здесь
