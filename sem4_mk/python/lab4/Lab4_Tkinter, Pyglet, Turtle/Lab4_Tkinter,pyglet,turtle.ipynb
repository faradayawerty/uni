# %% [markdown]
# # Лабораторная работа 4

# %% [markdown]
# ## Библиотеки tkinter, pyglet, turtle

# %% [markdown]
# ### Библиотека tkinter

# %% [markdown]
# **1. (1 балл)** Напишите конвертер по переводу из сантиметров в дюймы с полями ввода Extry, причем в поле вывода пользователь не должен иметь возможности что-то вводить.

# %%
# ✓

# %% [markdown]
# **2. (1 балл)** Напишите генератор случайных целых чисел. Воспользуйтесь виджетом Scale, чтобы можно было выбрать количество генерируемых чисел (от 1 до 10) из конкретного диапазона, который введет пользователь.

# %%
# ✓

# %% [markdown]
# **3. (1 балл)** Создать окно с текстовым полем и кнопкой. Программа должна проверять, что именно ввёл пользователь, и выводить в диалоговом окне информацию об этом. Варианты - положительное число, отрицательное число, текст, разные символы, пусто.

# %%
# ✓

# %% [markdown]
# **4. (1 балл)** Создать окно с 5 радиокнопками, у каждой из которых записано название цвета (цвета - на ваш выбор). Размер окна определяется пользователем (вводится с клавиатуры до появления окна). Диапазон возможных значений размера определите самостоятельно. Радиокнопки расположить по центру друг под другом. При нажатии на кнопку цвет окна изменяется на указанный в названии кнопки.

# %%
# Ваш код здесь

# %% [markdown]
# **5. (2 балла)** Напишите простой калькулятор, который умеет совершать базовые математические операции. Расположите кнопки для цифр от 0 до 9 и для операций: сложение, вычитание, умножение, деление, "=" и "Clear".

# %%
# ✓

# %% [markdown]
# ## Библиотека pyglet

# %% [markdown]
# **6. (1 балл)** Определить в какой четверти была нажата кнопка мыши и вывести название четверти и кнопку мыши (правая или левая) в этой же четверти.

# %%
# Ваш код здесь

# %% [markdown]
# **7. (1 балл)** Создать открытку по данным требованиям:
#
# • Фон - само окно, перекрашенное в любой цвет.
#
# • Передний план - загруженная картинка (обязательно меньше фона) и любой текст.
#
# Пример открытки приведен ниже.

# %%
from IPython.display import Image
Image("images/2_9.jpg")

# %%
# Ваш код здесь

# %% [markdown]
# **8. (1 балл)** Создание тематической анимации с несколькими планами:
# • Задний план - большая анимация (фон).
# • Передний план - анимация поменьше с прозрачным фоном (главный персонаж картины).
#
# Способы создания/загрузки анимации должны быть разными.
# Можно воспользоваться файлами из каталога images.

# %%
# Ваш код здесь

# %% [markdown]
# **9. (1 балл)** Напишите программу которая выводит плеер с тремя кнопками: пауза/воспроизведение, перемотка вперед и назад. Файл для воспроизведения пользователь может выбрать из предлагаемого списка (способ отображения выберите самостоятельно). Название воспроизводимой композиции видно пользователю.

# %% [markdown]
# ### Библиотека turtle

# %% [markdown]
# **10. (1 балл)** По центру формы нарисуйте Олимпийскую эмблему, а в каждом из 4 углов формы - восьмиконечную звезду (с углом поворота в 135 градусов). Углы звезды отметьте точками, радиусы которых зависят от толщины пера, цвет точек не должен совпадать с цветом пера. Подпишите координаты углов.

# %%
# Ваш код здесь

# %% [markdown]
# **11. (2 балла)** Нарисуйте несколько разных фигур (минимум 5 разной формы, цвета, размера, заливки) и создайте игру, активируемую кнопкой, в которой, управляя стрелками черепашкой, необходимо добраться до финиша, не задевая фигуры. При столкновении игра начинается заново. При выигрыше выдается сообщение.

# %%
# Ваш код здесь

# %% [markdown]
# **12. (2 балла)** Создайте объект - исходно квадрат красного цвета. С помощью методов обработки событий клавиатуры реализуйте следующие функции:
#
# 1) Управление движением квадратика (движение вперед, поворот налево, поворот направо, прыжок), квадратик оставляет за собой след желтого цвета той же ширины, что и сам объект.
#
# 2) Отображение текущих координат квадратика на холсте по нажатии на клавишу "С". При дальнейшем перемещении форма очищается.
#
# Ограничьте область перемещения квадратика прямоугольником произвольного размера. Границы области перемещения должны быть видимыми.
#
# Внизу окна нарисуйте три кнопки.
# * Первая кнопка будет при нажатии превращаться в круг и движущийся по форме объект при этом преобразуется в круг.
# * Вторая кнопка будет при нажатии превращаться в квадрат и движущийся по форме объект при этом преобразуется в квадрат.
# * Третья кнопка закрывает окно.

# %%
# Ваш код здесь

# %% [markdown]
# **13. (1 балл)** С помощью пиксельной графики изобразите на холсте черепаху из черепашек размером 16 * 16.

# %%
# Ваш код здесь

# %% [markdown]
# **14. (1 балл)** С помощью L-системы постройте фрактальное растение.
#
# Параметры системы:
#
# * Переменные: X F
# * Константы: + - [ ]
# * Аксиома: X
# * Правила: {X: F-[[X]+X]+F[+FX]-X, F: FF}
# * Угол: 25 градусов
#
#         "F" - рисовать отрезок, "-" - повернуть налево, "+" - повернуть направо, "X" - не соответствует ничему, "[" - запись в стек текущих позиции и угла, "]" - чтение из стека.

# %%
# Ваш код здесь

# %% [markdown]
# **15. (1-3 балла)** Используя возможности изученных библиотек, создать интересную анимацию с игровыми элементами по своему желанию и на своё усмотрение.

# %%
# Ваш код здесь
