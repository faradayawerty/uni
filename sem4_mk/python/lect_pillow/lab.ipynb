# %% [markdown]
# ## Лабораторная работа

# %% [markdown]
# **1.** Загрузить произвольное png-изображение в память компьютера
# 1. Из файла
# 2. Из URL
#
# Уменьшить его до размера 640x480, поменять каналы цветов с RGB на BGR. Сохранить в .bmp формате

# %%
# Ваш код здесь

# %% [markdown]
# **2.** Построить
# 1. Древо Пифагора
# 2. Треугольник серпинского
# 3. Круговой фрактал (https://ru.wikipedia.org/wiki/круговой_фрактал) N-ной итерации (N вводится с клавиатуры).
#
# Изображения должны быть цветными и сохраняться по введенному с клавиатуры пути

# %%
# Ваш код здесь

# %% [markdown]
# **3.** Дана папка pngs, содержащая png-изображения (01.png, 02.png, 03.png и т.д. до 99.png). Создать программно папку jpgs, заполнить её теми же изображениями, переведенными в формат jpg. Отфильтровать изображения так, чтобы
# 1. В первом изображении остался только красный канал, во втором - только зелёный. Цвет от первого изображения ко второму должен меняться постепенно.
# 2. Каждое последующее изображение должно быть всё более и более заблюреным.

# %%
# Ваш код здесь

# %% [markdown]
# **4.** Сформировать трехсекундную черно-белую гиф из шестидесяти кадров. Пусть N - номер кадра.
# Пиксель с координатами (x,y) закрашивается черным цветом, если abs(f<sup>50</sup>(x+yi)) < 2, f<sup>50</sup> - функция f(z) = z² - C, скомпозированная сама с собой 50 раз. i - мнимая единица, C = -0.5 + 0.2i + 0.2cos(2πN/60) + 0.1isin(2πN/60).
#
#
# Комплексные числа доступны в модуле complex.

# %%
# Ваш код здесь

# %% [markdown]
# **5.** Написать простенький графический редактор, используя tkinter и pillow. Графический интерфейс программы должен уметь создавать новое изображение, загружать изображение из файла сохранять изображение в трех форматах (.bmp, .jpg и .png), рисовать произвольные линии одним из десяти заданных цветов, фильтровать изображение одним из трёх фильтров.

# %%
# Ваш код здесь
